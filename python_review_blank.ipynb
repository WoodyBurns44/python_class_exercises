# %%
# !pip install nb_black
# Out:
# Collecting nb_black
#   Downloading nb_black-1.0.7.tar.gz (4.8 kB)
# Requirement already satisfied: ipython in /opt/anaconda3/lib/python3.8/site-packages (from nb_black) (7.16.1)
# Collecting black>='19.3'
#   Downloading black-20.8b1.tar.gz (1.1 MB)
#      |████████████████████████████████| 1.1 MB 1.3 MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#   WARNING: Requested black>='19.3' from https://files.pythonhosted.org/packages/dc/7b/5a6bbe89de849f28d7c109f5ea87b65afa5124ad615f3419e71beb29dc96/black-20.8b1.tar.gz#sha256=1c02557aa099101b9d21496f8a914e9ed2222ef70336404eeeac8edba836fbea (from nb_black), but installing version 20.8b1
# Requirement already satisfied: pygments in /opt/anaconda3/lib/python3.8/site-packages (from ipython->nb_black) (2.6.1)
# Requirement already satisfied: setuptools>=18.5 in /opt/anaconda3/lib/python3.8/site-packages (from ipython->nb_black) (49.2.0.post20200714)
# Requirement already satisfied: decorator in /opt/anaconda3/lib/python3.8/site-packages (from ipython->nb_black) (4.4.2)
# Requirement already satisfied: backcall in /opt/anaconda3/lib/python3.8/site-packages (from ipython->nb_black) (0.2.0)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /opt/anaconda3/lib/python3.8/site-packages (from ipython->nb_black) (4.8.0)
# Requirement already satisfied: traitlets>=4.2 in /opt/anaconda3/lib/python3.8/site-packages (from ipython->nb_black) (4.3.3)
# Requirement already satisfied: pickleshare in /opt/anaconda3/lib/python3.8/site-packages (from ipython->nb_black) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from ipython->nb_black) (3.0.5)
# Requirement already satisfied: jedi>=0.10 in /opt/anaconda3/lib/python3.8/site-packages (from ipython->nb_black) (0.17.1)
# Requirement already satisfied: appnope; sys_platform == "darwin" in /opt/anaconda3/lib/python3.8/site-packages (from ipython->nb_black) (0.1.0)
# Requirement already satisfied: regex>=2020.1.8 in /opt/anaconda3/lib/python3.8/site-packages (from black>='19.3'->nb_black) (2020.6.8)
# Requirement already satisfied: click>=7.1.2 in /opt/anaconda3/lib/python3.8/site-packages (from black>='19.3'->nb_black) (7.1.2)
# Collecting pathspec<1,>=0.6
#   Downloading pathspec-0.8.0-py2.py3-none-any.whl (28 kB)
# Requirement already satisfied: toml>=0.10.1 in /opt/anaconda3/lib/python3.8/site-packages (from black>='19.3'->nb_black) (0.10.1)
# Collecting mypy-extensions>=0.4.3
#   Downloading mypy_extensions-0.4.3-py2.py3-none-any.whl (4.5 kB)
# Collecting typed-ast>=1.4.0
#   Downloading typed_ast-1.4.1-cp38-cp38-macosx_10_15_x86_64.whl (224 kB)
#      |████████████████████████████████| 224 kB 3.2 MB/s eta 0:00:01
# Collecting appdirs
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: typing-extensions>=3.7.4 in /opt/anaconda3/lib/python3.8/site-packages (from black>='19.3'->nb_black) (3.7.4.2)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/lib/python3.8/site-packages (from pexpect; sys_platform != "win32"->ipython->nb_black) (0.6.0)
# Requirement already satisfied: ipython-genutils in /opt/anaconda3/lib/python3.8/site-packages (from traitlets>=4.2->ipython->nb_black) (0.2.0)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.8/site-packages (from traitlets>=4.2->ipython->nb_black) (1.15.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->nb_black) (0.2.5)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /opt/anaconda3/lib/python3.8/site-packages (from jedi>=0.10->ipython->nb_black) (0.7.0)
# Building wheels for collected packages: nb-black, black
#   Building wheel for nb-black (setup.py) ... done
#   Created wheel for nb-black: filename=nb_black-1.0.7-py3-none-any.whl size=5280 sha256=f8ef4f31edeaa46f4793a93ddb9d49842f74018cf5393459c5d7b9bdb77bdba3
#   Stored in directory: /Users/woodyburns/Library/Caches/pip/wheels/a6/5e/1e/a15614d6ea220d070043db3b650d73a8b4938aefd520496c11
#   Building wheel for black (PEP 517) ... done
#   Created wheel for black: filename=black-20.8b1-py3-none-any.whl size=124186 sha256=8b3eba52441e7a686804b343aea60af2d39c6a4cccd5fba6f7f47308b02dd2fc
#   Stored in directory: /Users/woodyburns/Library/Caches/pip/wheels/95/a4/59/10cd5378d52f92cdb45025f040e4686e10ae5217961c25fd66
# Successfully built nb-black black
# Installing collected packages: pathspec, mypy-extensions, typed-ast, appdirs, black, nb-black
# Successfully installed appdirs-1.4.4 black-20.8b1 mypy-extensions-0.4.3 nb-black-1.0.7 pathspec-0.8.0 typed-ast-1.4.1

# %%
# %reload_ext nb_black

# %% [markdown]
# ## Python Practice
#
# Just some made up exercises.
#
# Some additional practice:
#
# * https://codingbat.com/python
# * https://www.practicepython.org/
# * https://www.hackerrank.com/domains/python
# * https://www.codewars.com/collections/basic-python
#
# Links from slides:
# * https://automatetheboringstuff.com
# * https://realpython.com/python-beginner-tips/

# %% [markdown]
# ### Dictionary sum
#
# Write a function that accepts a dictionary and threshold value.  The function should sum all of the dictionary values who's keys are greater than or equal to the threshold.  The dictionary will have both numeric keys and values (ie `{1: 2, 3: 4, 5: 6}`).
#
# Example
#
# ```python
# d = {1: 2, 3: 4, 5: 6}
#
# your_function(d, 3)
# # Expected output is 10.
# # The keys 3 & 5 are greater than or equal to the threshold of 3.
# # The values corresponding to the keys 3 & 5 are 4 & 6, and 4 + 6 = 10.
# ```

# %%
def dict_add(d, thresh):
    sum = 0
    for key, value in d.items():
        if key >= thresh:
            sum += value
    return sum


dic = {1: 2, 3: 4, 5: 6}
dict_add(dic, 3)
# Out:
# 10

# %% [markdown]
# ### Pandas practice

# %% [markdown]
# > ##### Description
# > The data was extracted from the 1974 Motor Trend US magazine, and comprises fuel consumption and 10 aspects of automobile design and performance for 32 automobiles (1973–74 models).
# >
# > ##### Columns
# A data frame with 32 observations on 11 (numeric) variables.
# >
# > ```
# >  1. mpg    Miles/(US) gallon
# >  2. cyl    Number of cylinders
# >  3. disp   Displacement (cu.in.)
# >  4. hp     Gross horsepower
# >  5. drat   Rear axle ratio
# >  6. wt     Weight (1000 lbs)
# >  7. qsec   1/4 mile time
# >  8. vs     Engine (0 = V-shaped, 1 = straight)
# >  9. am     Transmission (0 = automatic, 1 = manual)
# > 10. gear   Number of forward gears
# > 11. carb   Number of carburetors
# > ```

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

mtcars_url = "https://gist.githubusercontent.com/ZeccaLehn/4e06d2575eb9589dbe8c365d61cb056c/raw/64f1660f38ef523b2a1a13be77b002b98665cdfe/mtcars.csv"

# %% [markdown]
# Read the data frame using `mtcars_url`

# %%
df = pd.read_csv(mtcars_url)

# %% [markdown]
# Print the first 8 rows of the dataframe.

# %%
df.head(8)
# Out:
#           Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# 5            Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# 6         Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# 7          Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2
# 5     1
# 6     4
# 7     2

# %% [markdown]
# Rename the first column to something more meaningful.

# %%
df.rename(columns={"Unnamed: 0": "Model"}, inplace=True)
df.head(10)
# Out:
#                Model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# 5            Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# 6         Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# 7          Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# 8           Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# 9           Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2
# 5     1
# 6     4
# 7     2
# 8     2
# 9     4

# %% [markdown]
# Plot the distribution of the `cyl` column.  Is this a continuous or discrete variable?

# %%
cyl_plot = plt.plot(df["cyl"])

# %% [markdown]
# What is the minimum value in the `mpg` column?

# %%
min_mpg = min(df["mpg"])
min_mpg
# Out:
# 10.4

# %% [markdown]
# What is the name of the car with `mpg` equal to `15.0`?

# %%
fifteen_mpg = df["mpg"] == 15.0
df.iloc[fifteen_mpg.values]
# Out:
#             Model   mpg  cyl   disp   hp  drat    wt  qsec  vs  am  gear  carb
# 30  Maserati Bora  15.0    8  301.0  335  3.54  3.57  14.6   0   1     5     8

# %% [markdown]
# What is the name of the car that has the best gas mileage?

# %%
mpg_sort = df.sort_values("mpg", ascending=False)
mpg_sort.head(20)
# mpg_sort.head(1)
# Out:
#                 Model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 19     Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   1   1
# 17           Fiat 128  32.4    4   78.7   66  4.08  2.200  19.47   1   1
# 27       Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90   1   1
# 18        Honda Civic  30.4    4   75.7   52  4.93  1.615  18.52   1   1
# 25          Fiat X1-9  27.3    4   79.0   66  4.08  1.935  18.90   1   1
# 26      Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.70   0   1
# 7           Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 2          Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 8            Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 20      Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1   0
# 31         Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.60   1   1
# 3      Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 1       Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 0           Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 29       Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.50   0   1
# 9            Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 24   Pontiac Firebird  19.2    8  400.0  175  3.08  3.845  17.05   0   0
# 4   Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5             Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 10          Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
#
#     gear  carb
# 19     4     1
# 17     4     1
# 27     5     2
# 18     4     2
# 25     4     1
# 26     5     2
# 7      4     2
# 2      4     1
# 8      4     2
# 20     3     1
# 31     4     2
# 3      3     1
# 1      4     4
# 0      4     4
# 29     5     6
# 9      4     4
# 24     3     2
# 4      3     2
# 5      3     1
# 10     4     4

# %% [markdown]
# Use your intuition from the variable descriptions and visulaizations to find 2 variables that appear to be *positively* correlated.

# %% [markdown]
# CYL and HP

# %% [markdown]
# Use your intuition from the variable descriptions and visulaizations to find 2 variables that appear to be *negatively* correlated.

# %% [markdown]
# MPG and HP

# %% [markdown]
# Identify a way to split the data into 2 groups and identify a numeric variable that would appropriate to apply a t-test to.  Split the data frame into these 2 groups.

# %%
# df.describe()
high_cyl = df["cyl"] > 6
high_cyl_df = df.iloc[high_cyl.values]
high_cyl_df.head(10)
# high_cyl_df.info()
# Out:
#                   Model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 11           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0   0
# 12           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   0   0
# 13          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0   0
# 14   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   0
# 15  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0
# 16    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0   0
# 21     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.87   0   0
# 22          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   0   0
#
#     gear  carb
# 4      3     2
# 6      3     4
# 11     3     3
# 12     3     3
# 13     3     3
# 14     3     4
# 15     3     4
# 16     3     4
# 21     3     2
# 22     3     2

# %%
low_cyl = df["cyl"] <= 6
low_cyl_df = df.iloc[low_cyl.values]
low_cyl_df.head(10)
# low_cyl_df.info()
# Out:
#              Model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0        Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1    Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2       Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3   Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 5          Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# 7        Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# 8         Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# 9         Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
# 10       Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0     4
# 17        Fiat 128  32.4    4   78.7   66  4.08  2.200  19.47   1   1     4
#
#     carb
# 0      4
# 1      4
# 2      1
# 3      1
# 5      1
# 7      2
# 8      2
# 9      4
# 10     4
# 17     1
